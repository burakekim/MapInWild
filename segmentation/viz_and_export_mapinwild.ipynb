# %%
from viz_utils import viz_single_id
# %load_ext autoreload
# %autoreload 2

# %%
dataset_root = r'C:\Dataset\DATASET\Dataset_'

# %%
viz_single_id(root = dataset_root,
              im_name = 555622236)

# %%
viz_single_id(root = dataset_root,
              im_name = 5955)

# %%
viz_single_id(root = dataset_root,
              im_name = 19442)

# %%
viz_single_id(root = dataset_root,
              im_name = 11496)

# %%
viz_single_id(root = dataset_root,
              im_name = 555556115)

# %%
viz_single_id(root = dataset_root,
              im_name = 367921)

# %%
viz_single_id(root = dataset_root,
              im_name = 555582)

# %%
viz_single_id(root = dataset_root,
              im_name = 107148)

# %%
viz_single_id(root = dataset_root,
              im_name = 366743)

# %%
viz_single_id(root = dataset_root,
              im_name = 372069)

# %%
viz_single_id(root = dataset_root,
              im_name = 357215)
